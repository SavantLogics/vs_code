# %% [markdown]
# Principal Component Analysis (PCA)

# %%
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %% [markdown]
# Create a range of 100 genes and a range of 5 wt and ko

# %%
genes = ['gene ' + str(i) for i in range(1,101)]
wt = ['wt ' + str(i) for i in range(1,6)]
ko = ['ko ' + str(i) for i in range(1,6)]

# %%
genes
# Out:
# ['gene 1',
#  'gene 2',
#  'gene 3',
#  'gene 4',
#  'gene 5',
#  'gene 6',
#  'gene 7',
#  'gene 8',
#  'gene 9',
#  'gene 10',
#  'gene 11',
#  'gene 12',
#  'gene 13',
#  'gene 14',
#  'gene 15',
#  'gene 16',
#  'gene 17',
#  'gene 18',
#  'gene 19',
#  'gene 20',
#  'gene 21',
#  'gene 22',
#  'gene 23',
#  'gene 24',
#  'gene 25',
#  'gene 26',
#  'gene 27',
#  'gene 28',
#  'gene 29',
#  'gene 30',
#  'gene 31',
#  'gene 32',
#  'gene 33',
#  'gene 34',
#  'gene 35',
#  'gene 36',
#  'gene 37',
#  'gene 38',
#  'gene 39',
#  'gene 40',
#  'gene 41',
#  'gene 42',
#  'gene 43',
#  'gene 44',
#  'gene 45',
#  'gene 46',
#  'gene 47',
#  'gene 48',
#  'gene 49',
#  'gene 50',
#  'gene 51',
#  'gene 52',
#  'gene 53',
#  'gene 54',
#  'gene 55',
#  'gene 56',
#  'gene 57',
#  'gene 58',
#  'gene 59',
#  'gene 60',
#  'gene 61',
#  'gene 62',
#  'gene 63',
#  'gene 64',
#  'gene 65',
#  'gene 66',
#  'gene 67',
#  'gene 68',
#  'gene 69',
#  'gene 70',
#  'gene 71',
#  'gene 72',
# ...

# %%
wt
# Out:
# ['wt 1', 'wt 2', 'wt 3', 'wt 4', 'wt 5']

# %%
ko
# Out:
# ['ko 1', 'ko 2', 'ko 3', 'ko 4', 'ko 5']

# %% [markdown]
# Make the columns wt and ko
# Make the index genes

# %%
data = pd.DataFrame(columns=[*wt, *ko], index=genes)

# %%
data.head()
# Out:
#        wt 1 wt 2 wt 3 wt 4 wt 5 ko 1 ko 2 ko 3 ko 4 ko 5
# gene 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# gene 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# gene 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# gene 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# gene 5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
for gene in data.index:
    data.loc[gene, 'wt 1' : 'wt 5'] = np.random.poisson(lam=rd.randrange(10,100), size=5)
    data.loc[gene, 'ko 1' : 'ko 5'] = np.random.poisson(lam=rd.randrange(10,100), size=5)

# %%
data.head()
# Out:
#        wt 1 wt 2 wt 3 wt 4 wt 5 ko 1 ko 2 ko 3 ko 4 ko 5
# gene 1   88   83   74   78   73   22   23   19   25   22
# gene 2   45   48   54   53   61   89   79   70   64   77
# gene 3   10   20   16   15   12   33   28   28   27   29
# gene 4   81   85   83   82   80   28   28   29   37   32
# gene 5   60   46   68   60   80    6   18   10   13   10

# %%
print(data.shape)
# Out:
# (100, 10)

# %%
data.head()
# Out:
#        wt 1 wt 2 wt 3 wt 4 wt 5 ko 1 ko 2 ko 3 ko 4 ko 5
# gene 1   88   83   74   78   73   22   23   19   25   22
# gene 2   45   48   54   53   61   89   79   70   64   77
# gene 3   10   20   16   15   12   33   28   28   27   29
# gene 4   81   85   83   82   80   28   28   29   37   32
# gene 5   60   46   68   60   80    6   18   10   13   10

# %%
scaled_data = preprocessing.scale(data.T)

# %%
print(scaled_data)
# Out:
# [[ 1.2946941  -1.37767997 -1.52388149  0.94803991  0.84728271  1.19878056
#   -1.36410455  1.19220189  0.3614194   0.69995679  1.42167564  1.26139054
#   -0.99283466  1.27802391 -1.00738975 -0.77488969 -0.6648225   0.25841384
#   -1.24244674 -0.67973321 -1.16178505 -0.54060235 -0.62780854  2.41574002
#    0.58111856 -0.98383265 -0.9592703   0.98121403  1.05112389 -0.67262657
#    1.77041719  1.47849781  0.35654729  1.4069082   0.39631199  0.65478146
#    0.60494569  1.26595494 -1.76417759  0.36077573  0.84454839  0.09805807
#    0.88106129 -1.07413417  1.02678459 -1.51739999 -1.12991483 -0.28514907
#    1.37669759 -0.9226482   1.42231934 -0.58584716 -0.82005991  1.50119477
#   -0.57995237  0.89970916 -0.88332031 -1.2150965   1.21298497  1.122778
#   -0.73430379 -0.34774375  1.44418837 -1.46064198  1.04277449 -1.21016654
#    1.30291834 -0.75194452 -0.32729207 -0.76883162  0.13927901  1.2286881
#   -0.8760617  -0.85578554 -1.03897343  0.42008403 -0.25444155  1.17993609
# ...

# %%
pca = PCA()
pca.fit(scaled_data)
pca_data = pca.transform(scaled_data)

# %%
pca_data
# Out:
# array([[ 8.65335581e+00,  3.30196254e+00, -3.48594083e+00,
#         -9.23932995e-02,  1.91338104e+00, -2.75407749e-01,
#          3.25242950e+00, -2.02887175e-01,  2.93954648e-02,
#          2.17881269e-15],
#        [ 8.15810824e+00, -4.08756619e-02, -4.46834071e-01,
#          4.27892627e+00, -1.89011016e+00, -2.23449795e+00,
#         -1.54523549e+00, -1.56908969e+00, -9.67620962e-01,
#         -2.48499138e-16],
#        [ 7.22458272e+00, -1.06253805e+00,  5.36727047e+00,
#         -9.65633349e-01, -7.28305131e-01, -1.84973251e+00,
#          1.69179311e+00,  1.45951296e+00,  9.30302332e-01,
#          4.26741975e-16],
#        [ 8.30200686e+00,  1.38560707e+00, -9.93621902e-01,
#         -8.07166008e-01, -2.71706852e+00,  3.58521616e+00,
#         -1.62409515e+00,  1.24335782e+00,  1.41328520e+00,
#          6.83481050e-16],
#        [ 7.98549582e+00, -3.63568019e+00,  1.57283496e-01,
#         -2.44765772e+00,  3.42294952e+00,  7.59341840e-01,
# ...

# %%
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
labels = ['PC ' + str(x) for x in range(1, len(per_var)+1)]

# %%
per_var
# Out:
# array([65.2,  7.6,  6.1,  4.9,  4.4,  3.8,  3. ,  2.7,  2.4,  0. ])

# %%
labels
# Out:
# ['PC 1',
#  'PC 2',
#  'PC 3',
#  'PC 4',
#  'PC 5',
#  'PC 6',
#  'PC 7',
#  'PC 8',
#  'PC 9',
#  'PC 10']
