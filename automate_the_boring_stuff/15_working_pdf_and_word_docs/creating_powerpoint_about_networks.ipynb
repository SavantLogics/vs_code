# %%
from pptx import Presentation

# Create a PowerPoint presentation
prs = Presentation()

# Slide 1: Title Slide
slide = prs.slides.add_slide(prs.slide_layouts[0])
title = slide.shapes.title
subtitle = slide.placeholders[1]
title.text = "Understanding Computer Networks: A High-Level Overview"
subtitle.text = "A Simplified Framework for Connectivity and Troubleshooting\n\nDisclaimer: This is a high-level overview intended for educational purposes."

# Slide 2: Introduction
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Introduction"
content.text = (
    "Situation: Importance of computer networks in a digital world.\n\n"
    "Complication: Challenges in understanding networks.\n\n"
    "Question: How can we simplify understanding?\n\n"
    "Answer: A structured approach to core networking concepts."
)

# Slide 3: The OSI Model
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "The OSI Model"
content.text = (
    "Overview: Seven-layer model for network communication.\n\n"
    "Focus on Key Layers:\n"
    "- Physical: Cables and switches.\n"
    "- Network: Data routing.\n"
    "- Application: End-user interaction."
)

# Slide 4: OSI Model - Practical Relevance
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "OSI Model - Practical Relevance"
content.text = (
    "How understanding the OSI model helps in troubleshooting.\n\n"
    "Diagram: The 7 OSI layers and their functions."
)

# Slide 5: LANs and Mesh Topology
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "LANs and Mesh Topology"
content.text = (
    "LANs: What they are and why they matter.\n\n"
    "Mesh Topology:\n"
    "- Reliability, scalability, and redundancy."
)

# Slide 6: Common LAN Configurations
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Common LAN Configurations"
content.text = (
    "Topologies:\n"
    "- Bus, Star, Ring, Tree, Mesh.\n\n"
    "Technologies:\n"
    "- Ethernet, Wi-Fi, Powerline."
)

# Slide 7: Installing a Physical Network
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Installing a Physical Network"
content.text = (
    "Steps to install:\n"
    "- Floor planning.\n"
    "- Cable runs.\n"
    "- MDF and IDF setup.\n\n"
    "Importance of proper cable management."
)

# Slide 8: Routers
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Routers"
content.text = (
    "Functionality:\n"
    "- Packet switching.\n"
    "- Routing tables.\n\n"
    "Types of Routers:\n"
    "- Home, Business, Network."
)

# Slide 9: Benefits of Routers
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Benefits of Routers"
content.text = (
    "Connectivity: Linking networks.\n\n"
    "Security: Firewalls and network segmentation.\n\n"
    "Performance: Efficient data flow."
)

# Slide 10: Switches
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Switches"
content.text = (
    "Purpose: Connecting devices within a LAN.\n\n"
    "How They Work:\n"
    "- Packet switching.\n"
    "- MAC address tables."
)

# Slide 11: VLANs
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "VLANs"
content.text = (
    "Definition: Logical grouping of devices.\n\n"
    "Benefits:\n"
    "- Improved security.\n"
    "- Reduced broadcast traffic.\n"
    "- Flexible network design."
)

# Slide 12: MDFs and IDFs
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "MDFs and IDFs"
content.text = (
    "Roles:\n"
    "- MDF: Core connectivity hub.\n"
    "- IDF: Regional distribution points.\n\n"
    "Diagram: Network layout showing MDF and IDF connections."
)

# Slide 13: Troubleshooting Techniques
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Troubleshooting Techniques"
content.text = (
    "Signs of Network Issues:\n"
    "- Slow performance.\n"
    "- Frequent disconnections.\n"
    "- Inaccessible resources.\n\n"
    "Tools:\n"
    "- Wireshark: Traffic analysis.\n"
    "- NMap: Port scanning."
)

# Slide 14: Practical Troubleshooting Example
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Practical Troubleshooting Example"
content.text = (
    "Scenario: Diagnosing slow network performance.\n\n"
    "Step-by-step:\n"
    "1. Analyze traffic with Wireshark.\n"
    "2. Check routing tables on routers."
)

# Slide 15: Conclusion
slide = prs.slides.add_slide(prs.slide_layouts[1])
title = slide.shapes.title
content = slide.placeholders[1]
title.text = "Conclusion"
content.text = (
    "Summary of key points:\n"
    "- OSI Model and LANs.\n"
    "- Networking devices and configurations.\n"
    "- Troubleshooting tools.\n\n"
    "Final thought: Effective management relies on foundational understanding."
)

# Save the presentation
file_path = "Understanding_Computer_Networks_Presentation.pptx"
prs.save(file_path)

file_path
