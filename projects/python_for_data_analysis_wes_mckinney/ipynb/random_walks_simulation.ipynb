# %% [markdown]
# ## Random Walks

# %%
import random

# %%
position = 0
walk = [position]
steps = 2000 # Giving the walk a two thousand steps
for i in range(steps): # Step through the for loop 
    step = 1 if random.randint(0, 1) else -1 # Append to step either 0, 1, or -1 randomly
    position += step 
    walk.append(position) # Append it to positions list

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(walk[: 100]) # Plot just the first 100 values from the walk

# %%
plt.plot(walk[101:200]) # Plot the second 100 to 200 values

# %% [markdown]
# ## 1000 Coin Flips

# %%
import numpy as np
import math

# %%
nsteps = 1000
draws = np.random.randint(0, 2, size = nsteps)
steps = np.where(draws > 0,1, -1)

# %%
walk = steps.cumsum()

# %%
walk
# Out:
# array([-1,  0, -1,  0,  1,  2,  3,  4,  5,  4,  3,  4,  3,  4,  5,  6,  7,
#         8,  9, 10, 11, 10,  9, 10, 11, 12, 13, 14, 15, 14, 13, 14, 15, 14,
#        15, 16, 17, 18, 17, 18, 17, 18, 19, 18, 19, 18, 17, 16, 15, 16, 17,
#        18, 19, 20, 19, 20, 21, 20, 19, 20, 21, 22, 21, 20, 19, 18, 19, 20,
#        19, 20, 21, 22, 21, 20, 19, 20, 19, 18, 17, 16, 17, 16, 15, 16, 17,
#        16, 15, 14, 15, 14, 15, 14, 15, 16, 15, 16, 17, 16, 17, 16, 15, 16,
#        17, 18, 19, 20, 21, 20, 19, 18, 19, 18, 19, 18, 17, 18, 17, 18, 17,
#        18, 19, 18, 19, 20, 19, 18, 17, 16, 17, 18, 17, 18, 19, 20, 21, 20,
#        19, 20, 21, 20, 19, 18, 17, 16, 17, 18, 19, 18, 17, 16, 17, 18, 17,
#        16, 17, 18, 19, 20, 21, 22, 21, 22, 21, 22, 21, 22, 21, 20, 21, 20,
#        21, 20, 19, 20, 19, 18, 17, 18, 17, 18, 19, 20, 21, 20, 19, 18, 19,
#        20, 21, 22, 23, 24, 25, 24, 23, 24, 23, 22, 23, 22, 21, 20, 21, 22,
# ...

# %%
walk.min()
# Out:
# -1

# %%
walk.max()
# Out:
# 44

# %%
walk.mean()
# Out:
# 24.676

# %% [markdown]
# ## Simulating Many Random Walks

# %%
nwalks = 5000
nsteps = 1000
draws = np.random.randint(0, 2, size=(nwalks, nsteps))
steps = np.where(draws > 0, 1, -1)
walks = steps.cumsum(1)

# %%
walks
# Out:
# array([[ -1,   0,  -1, ...,  34,  33,  32],
#        [  1,   2,   1, ..., -38, -39, -40],
#        [ -1,   0,  -1, ...,  20,  19,  18],
#        ...,
#        [  1,   2,   1, ...,  16,  17,  18],
#        [ -1,   0,  -1, ...,  28,  29,  30],
#        [ -1,   0,  -1, ...,  30,  29,  28]])

# %%
walks.min()
# Out:
# -113

# %%
walks.max()
# Out:
# 123

# %%
walks.mean()
# Out:
# 0.4148108
