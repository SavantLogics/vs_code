# %%
import csv
import pandas as pd
import numpy as np

# %%
devices = pd.read_csv('C:/Users/rhawkins/Downloads/Downloaded_CSVs/district_working_hotspots.csv')

# %%
# Check the Transposed column

devices
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 IMEI
# ...

# %%
devices.T
# Out:
#        ['356640114303962'
#         '356640114330163'
#         '356640114333134'
#         '356640114506416'
#         '356640114614129'
#         '356640114624532'
#         '356640114625836'
#         '356640114632618'
#         '356640114632907'
#         '356640114634598'
#         '356640114696027'
#         '356640114698965'
#         '356640114716973'
#         '356640115124144'
#         '356640115133350'
#         '356640115147301'
#         '356640115161104'
#         '356640115165121'
#         '356640115168380'
#         '356640115178967'
#         '356640115203013'
#         '356640115206990'
#         '356640115207105'
#         '356640115207279'
#         '356640115208582'
#         '356640115211776'
#         '356640115212592'
#         '356640115214820'
#         '356640115429782'
#         '356640115430483'
#         '356640115431846'
#         '356640115432935'
#         '356640115435409'
#         '356640115436266'
#         '356640115436654'
# ...

# %%
devices.T.to_csv('C:/Users/rhawkins/Downloads/Downloaded_CSVs/district_working_hotspots.csv')
